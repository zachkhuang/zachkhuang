# %% [markdown]
# # DATA1030 FINAL PROJECT
#
# ## Zachk Huang

# %% [markdown]
# ### I. Data Cleaning and Renaming

# %%
import pandas as pd
df = pd.read_stata('cepsw1studentEN.dta',convert_categoricals=False)

# %%
print(df.shape)
print(df.head)
print(df.dtypes)
# Out:
# (19487, 150)
# <bound method NDFrame.head of        grade9  stcog     stdchn     stdmat     stdeng  a01    a02a  a03  a04  \
# 0           0     11  76.882126  67.297188  74.877319  2.0  2001.0  1.0  2.0
# 1           0     17  73.269005  71.416794  74.877319  1.0  2001.0  1.0  1.0
# 2           0     12  71.462448  42.579571  78.012741  1.0  2001.0  1.0  1.0
# 3           0     10  69.655891  70.043594  55.019653  2.0  2001.0  1.0  2.0
# 4           0     10  76.882126  75.536400  78.012741  NaN  2000.0  1.0  3.0
# ...       ...    ...        ...        ...        ...  ...     ...  ...  ...
# 19482       1      5  63.574070        NaN  65.303009  2.0  1999.0  1.0  1.0
# 19483       1      2  52.711227  58.570225  51.993042  1.0  1998.0  1.0  1.0
# 19484       1      8  44.952053  49.569790  51.651760  1.0  1998.0  1.0  1.0
# 19485       1      5        NaN  60.370312  50.969200  1.0  1999.0  1.0  1.0
# 19486       1      5  42.882938  48.669746  49.604073  1.0  1998.0  1.0  2.0
#
#        a05  ...  b2804  b2805  b2806  b29  b30  b31  b32   b33  b34  b35
# 0      2.0  ...    6.0    5.0    5.0  5.0  2.0  8.0  4.0   6.0  3.0  4.0
# 1      1.0  ...    6.0    3.0    3.0  5.0  2.0  7.0  2.0  11.0  3.0  4.0
# 2      2.0  ...    4.0    3.0    3.0  5.0  3.0  7.0  4.0   2.0  3.0  3.0
# 3      2.0  ...    4.0    4.0    4.0  5.0  3.0  3.0  2.0   6.0  4.0  3.0
# 4      1.0  ...    5.0    3.0    3.0  3.0  2.0  7.0  3.0   4.0  3.0  3.0
# ...    ...  ...    ...    ...    ...  ...  ...  ...  ...   ...  ...  ...
# 19482  1.0  ...    2.0    1.0    2.0  5.0  2.0  7.0  3.0   1.0  3.0  2.0
# 19483  1.0  ...    5.0    4.0    5.0  5.0  3.0  9.0  3.0   5.0  4.0  4.0
# 19484  1.0  ...    4.0    3.0    4.0  4.0  4.0  7.0  4.0  11.0  6.0  3.0
# 19485  1.0  ...    2.0    1.0    2.0  5.0  4.0  5.0  3.0  10.0  2.0  2.0
# 19486  1.0  ...    5.0    1.0    1.0  5.0  3.0  7.0  4.0   9.0  6.0  4.0
#
# [19487 rows x 150 columns]>
# grade9       int8
# stcog        int8
# stdchn    float32
# stdmat    float32
# stdeng    float32
#            ...
# b31       float64
# b32       float64
# b33       float64
# b34       float64
# b35       float64
# Length: 150, dtype: object

# %%
df['a1801']=6-df['a1801']
df['a1802']=6-df['a1802']
df['a1803']=6-df['a1803']
df['a1804']=6-df['a1804']
df['a1805']=6-df['a1805']
df['y'] = df[['a1801', 'a1802', 'a1803', 'a1804', 'a1805']].mean(axis=1)
print(df['y'].value_counts().sort_index())
df = df.drop(columns=['a1801', 'a1802', 'a1803', 'a1804', 'a1805'])
# Out:
# y
# 1.000000     247
# 1.200000      27
# 1.400000      53
# 1.500000       1
# 1.600000      59
# 1.750000       1
# 1.800000      87
# 2.000000     216
# 2.200000     178
# 2.250000       2
# 2.333333       1
# 2.400000     212
# 2.500000      11
# 2.600000     308
# 2.666667       1
# 2.750000       5
# 2.800000     382
# 3.000000    1126
# 3.200000     826
# 3.250000      16
# 3.333333       4
# 3.400000    1217
# 3.500000      30
# 3.600000    1515
# 3.666667       4
# 3.750000      40
# 3.800000    1754
# 4.000000    2379
# 4.200000    1867
# 4.250000      25
# 4.333333       2
# 4.400000    1599
# 4.500000      23
# 4.600000    1475
# 4.666667       1
# 4.750000       9
# 4.800000    1074
# 5.000000    2314
# Name: count, dtype: int64
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/651502360.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['y'] = df[['a1801', 'a1802', 'a1803', 'a1804', 'a1805']].mean(axis=1)

# %%
for col in df.columns:
    print(f"Value counts for {col}:")
    print(df[col].value_counts(dropna=False))  # include NaN counts
    print("\n")
# Out:
# Value counts for grade9:
# grade9
# 0    10279
# 1     9208
# Name: count, dtype: int64
#
#
# Value counts for stcog:
# stcog
# 10    1917
# 9     1872
# 11    1851
# 8     1798
# 12    1699
# 7     1565
# 13    1455
# 6     1274
# 14    1221
# 5     1021
# 15     910
# 4      726
# 16     639
# 3      426
# 17     389
# 18     234
# 2      204
# 19     129
# 1       71
# 0       37
# 20      36
# 21       8
# 22       5
# Name: count, dtype: int64
#
#
# Value counts for stdchn:
# stdchn
# NaN          486
# 74.356026     14
# 70.000000     14
# 73.138969     14
# 70.470863     12
#             ...
# 37.324409      1
# 70.657074      1
# 72.689552      1
# 64.966133      1
# 42.882938      1
# Name: count, Length: 8809, dtype: int64
#
#
# Value counts for stdmat:
# stdmat
# NaN          497
# 76.736839     20
# 78.926414     19
# 78.500458     17
# 79.503906     13
#             ...
# 76.932381      1
# 56.583370      1
# 62.306530      1
# 72.163086      1
# 48.669746      1
# Name: count, Length: 10903, dtype: int64
#
#
# Value counts for stdeng:
# stdeng
# NaN          491
# 77.185310     19
# 73.857323     13
# 76.625916     13
# 78.648331     12
#             ...
# 52.577759      1
# 44.207321      1
# 82.711334      1
# 58.628723      1
# 51.651760      1
# Name: count, Length: 11305, dtype: int64
#
#
# Value counts for a01:
# a01
# 1.0    9875
# 2.0    9341
# NaN     271
# Name: count, dtype: int64
#
#
# Value counts for a02a:
# a02a
# 1999.0    5130
# 2001.0    4923
# 2000.0    4252
# 1998.0    3675
# 1997.0     767
# NaN        405
# 2002.0     209
# 1996.0     126
# Name: count, dtype: int64
#
#
# Value counts for a03:
# a03
# 1.0    17740
# 8.0     1266
# 3.0      210
# 4.0      137
# NaN       50
# 2.0       41
# 6.0       27
# 5.0       16
# Name: count, dtype: int64
#
#
# Value counts for a04:
# a04
# 1.0    14439
# 2.0     4024
# 3.0      655
# NaN      369
# Name: count, dtype: int64
#
#
# Value counts for a05:
# a05
# 1.0    15681
# 2.0     3448
# NaN      358
# Name: count, dtype: int64
#
#
# Value counts for a06:
# a06
# 1.0    10025
# 2.0     4824
# 3.0     3702
# NaN      893
# 4.0       43
# Name: count, dtype: int64
#
#
# Value counts for a07:
# a07
# 0.0     13651
# NaN       852
# 13.0      445
# 1.0       430
# 6.0       428
# 12.0      428
# 7.0       404
# 3.0       388
# 5.0       366
# 10.0      322
# 8.0       317
# 9.0       269
# 11.0      266
# 2.0       251
# 4.0       246
# 14.0      215
# 15.0      145
# 16.0       63
# 17.0        1
# Name: count, dtype: int64
#
#
# Value counts for a08:
# a08
# 1.0    18628
# 2.0      571
# NaN      288
# Name: count, dtype: int64
#
#
# Value counts for a09:
# a09
# 2.0    12830
# NaN     2739
# 1.0     2665
# 3.0     1253
# Name: count, dtype: int64
#
#
# Value counts for a10:
# a10
# 2.0    13672
# 3.0     2846
# 1.0     2765
# NaN      204
# Name: count, dtype: int64
#
#
# Value counts for a11:
# a11
# 3.0    13463
# 2.0     2455
# 4.0     1554
# 6.0     1193
# 1.0      460
# NaN      223
# 5.0      139
# Name: count, dtype: int64
#
#
# Value counts for a13:
# a13
# 160.0    2007
# 165.0    1533
# 155.0    1047
# 170.0     957
# 163.0     856
#          ...
# 192.0       2
# 197.0       2
# 191.0       1
# 193.0       1
# 200.0       1
# Name: count, Length: 67, dtype: int64
#
#
# Value counts for a14:
# a14
# NaN      1634
# 100.0    1450
# 90.0     1211
# 80.0      951
# 110.0     880
#          ...
# 204.0       1
# 196.0       1
# 179.0       1
# 208.0       1
# 214.0       1
# Name: count, Length: 157, dtype: int64
#
#
# Value counts for a15:
# a15
# 3.0    7901
# 1.0    5714
# 2.0    5684
# NaN     188
# Name: count, dtype: int64
#
#
# Value counts for a16:
# a16
# 2.0    17758
# 1.0     1586
# NaN      143
# Name: count, dtype: int64
#
#
# Value counts for a17:
# a17
# 5.0    7240
# 4.0    6778
# 3.0    4472
# 2.0     713
# NaN     162
# 1.0     122
# Name: count, dtype: int64
#
#
# Value counts for b01:
# b01
# 2.0    11024
# 1.0     8458
# NaN        5
# Name: count, dtype: int64
#
#
# Value counts for b03:
# b03
# NaN    9218
# 1.0    5659
# 2.0    3888
# 3.0     722
# Name: count, dtype: int64
#
#
# Value counts for b0401:
# b0401
# 1.0    16566
# 0.0     2630
# NaN      291
# Name: count, dtype: int64
#
#
# Value counts for b0402:
# b0402
# 1.0    15451
# 0.0     3745
# NaN      291
# Name: count, dtype: int64
#
#
# Value counts for b0403:
# b0403
# 0.0    11433
# 1.0     7870
# NaN      184
# Name: count, dtype: int64
#
#
# Value counts for b0404:
# b0404
# 0.0    13350
# 1.0     5846
# NaN      291
# Name: count, dtype: int64
#
#
# Value counts for b0405:
# b0405
# 0.0    17241
# 1.0     1955
# NaN      291
# Name: count, dtype: int64
#
#
# Value counts for b0406:
# b0406
# 0.0    18902
# 1.0      294
# NaN      291
# Name: count, dtype: int64
#
#
# Value counts for b0501:
# b0501
# 0.0    12486
# NaN     3988
# 1.0     3013
# Name: count, dtype: int64
#
#
# Value counts for b0502:
# b0502
# 0.0    10938
# 1.0     4561
# NaN     3988
# Name: count, dtype: int64
#
#
# Value counts for b0503:
# b0503
# 0.0    11339
# 1.0     4160
# NaN     3988
# Name: count, dtype: int64
#
#
# Value counts for b0504:
# b0504
# 1.0    7753
# 0.0    7746
# NaN    3988
# Name: count, dtype: int64
#
#
# Value counts for b06:
# b06
# 3.0    7853
# 2.0    4075
# 6.0    2573
# 8.0    1231
# 4.0    1127
# 7.0    1022
# 1.0     722
# NaN     358
# 5.0     346
# 9.0     180
# Name: count, dtype: int64
#
#
# Value counts for b07:
# b07
# 3.0    8448
# 6.0    3293
# 2.0    2837
# 8.0    1525
# 7.0    1102
# 4.0    1085
# 5.0     404
# NaN     394
# 9.0     278
# 1.0     121
# Name: count, dtype: int64
#
#
# Value counts for b08a:
# b08a
# 8.0     4791
# 7.0     3282
# 6.0     2644
# 5.0     2093
# 9.0     1756
# 3.0     1068
# 10.0    1048
# 2.0      873
# 4.0      751
# 1.0      648
# NaN      533
# Name: count, dtype: int64
#
#
# Value counts for b08b:
# b08b
# 8.0     4208
# 7.0     3418
# 4.0     3293
# 5.0     1646
# 6.0     1393
# 2.0     1371
# 3.0     1171
# 1.0      987
# 10.0     958
# NaN      536
# 9.0      506
# Name: count, dtype: int64
#
#
# Value counts for b09:
# b09
# 3.0    14126
# 4.0     2113
# 2.0     2036
# NaN      796
# 1.0      292
# 5.0      124
# Name: count, dtype: int64
#
#
# Value counts for b1001:
# b1001
# 1.0    17245
# 2.0     1606
# NaN      636
# Name: count, dtype: int64
#
#
# Value counts for b1002:
# b1002
# 1.0    16943
# 2.0     1892
# NaN      652
# Name: count, dtype: int64
#
#
# Value counts for b1003:
# b1003
# 2.0    15856
# 1.0     3137
# NaN      494
# Name: count, dtype: int64
#
#
# Value counts for b11:
# b11
# 1.0    15148
# 2.0     3950
# NaN      389
# Name: count, dtype: int64
#
#
# Value counts for b12:
# b12
# 3.0    6750
# 4.0    4677
# 5.0    2923
# 2.0    2587
# 1.0    2495
# NaN      55
# Name: count, dtype: int64
#
#
# Value counts for b13:
# b13
# 2.0    11640
# 0.0     5988
# 1.0     1624
# NaN      235
# Name: count, dtype: int64
#
#
# Value counts for b14a1:
# b14a1
# 2.0     5153
# 1.0     4463
# 3.0     3474
# 0.0     2711
# 4.0     1353
# 5.0      709
# NaN      567
# 6.0      249
# 10.0     210
# 8.0      153
# 12.0      83
# 9.0       81
# 7.0       81
# 20.0      37
# 11.0      33
# 15.0      32
# 14.0      19
# 24.0      19
# 13.0      17
# 18.0      10
# 16.0       8
# 21.0       7
# 17.0       7
# 19.0       5
# 22.0       3
# 23.0       3
# Name: count, dtype: int64
#
#
# Value counts for b14a2:
# b14a2
# 0.0     8559
# 30.0    6450
# 20.0     782
# NaN      771
# 40.0     551
# 10.0     494
# 50.0     418
# 15.0     311
# 45.0     296
# 5.0      123
# 25.0      99
# 35.0      74
# 12.0      48
# 3.0       38
# 59.0      35
# 2.0       31
# 55.0      30
# 1.0       30
# 32.0      27
# 11.0      25
# 23.0      21
# 24.0      21
# 13.0      20
# 4.0       18
# 6.0       17
# 9.0       14
# 21.0      14
# 36.0      13
# 22.0      13
# 31.0      10
# 14.0       8
# 48.0       8
# 33.0       8
# 7.0        8
# 8.0        6
# 52.0       6
# 49.0       6
# 56.0       6
# 18.0       6
# 27.0       6
# 19.0       5
# 43.0       5
# 34.0       5
# 54.0       5
# 42.0       5
# 51.0       5
# 47.0       4
# 28.0       4
# 44.0       4
# 38.0       3
# 29.0       3
# 46.0       3
# 53.0       3
# 37.0       3
# 41.0       2
# 58.0       2
# 17.0       2
# 16.0       2
# 26.0       1
# Name: count, dtype: int64
#
#
# Value counts for b14b1:
# b14b1
# 2.0     4763
# 1.0     3422
# 3.0     3345
# 0.0     2172
# 4.0     2035
# 5.0     1526
# 6.0      673
# NaN      451
# 8.0      303
# 7.0      236
# 10.0     213
# 12.0     105
# 9.0       96
# 11.0      29
# 20.0      22
# 24.0      20
# 15.0      16
# 13.0      12
# 18.0      12
# 16.0      11
# 14.0      11
# 23.0       5
# 17.0       3
# 21.0       2
# 19.0       2
# 22.0       2
# Name: count, dtype: int64
#
#
# Value counts for b14b2:
# b14b2
# 0.0     10850
# 30.0     4615
# NaN       815
# 20.0      586
# 40.0      529
# 50.0      523
# 10.0      461
# 45.0      216
# 15.0      174
# 5.0        95
# 25.0       75
# 35.0       63
# 1.0        44
# 2.0        31
# 55.0       31
# 59.0       26
# 3.0        24
# 12.0       23
# 9.0        18
# 4.0        16
# 32.0       16
# 23.0       14
# 21.0       14
# 11.0       14
# 6.0        13
# 56.0       12
# 42.0       11
# 7.0        11
# 24.0       10
# 13.0       10
# 54.0        9
# 34.0        9
# 8.0         9
# 28.0        8
# 17.0        7
# 29.0        7
# 14.0        7
# 52.0        6
# 43.0        6
# 18.0        6
# 22.0        5
# 49.0        5
# 41.0        5
# 48.0        5
# 16.0        5
# 53.0        4
# 58.0        4
# 31.0        4
# 38.0        4
# 39.0        4
# 27.0        4
# 36.0        4
# 26.0        4
# 19.0        4
# 47.0        4
# 33.0        3
# 44.0        2
# 46.0        1
# 37.0        1
# 51.0        1
# Name: count, dtype: int64
#
#
# Value counts for b15a1:
# b15a1
# 0.0     12823
# 1.0      2911
# 2.0      1663
# 3.0       863
# NaN       383
# 4.0       377
# 5.0       202
# 6.0        69
# 10.0       58
# 8.0        33
# 7.0        22
# 9.0        15
# 12.0       15
# 15.0       12
# 11.0        9
# 20.0        9
# 24.0        5
# 13.0        4
# 14.0        3
# 16.0        3
# 21.0        2
# 23.0        2
# 22.0        2
# 19.0        1
# 17.0        1
# Name: count, dtype: int64
#
#
# Value counts for b15a2:
# b15a2
# 0.0     14813
# 30.0     2653
# NaN       421
# 20.0      418
# 10.0      281
# 40.0      230
# 50.0      187
# 45.0      108
# 15.0       83
# 5.0        55
# 25.0       27
# 1.0        25
# 35.0       20
# 3.0        18
# 12.0       12
# 59.0        9
# 2.0         9
# 21.0        8
# 6.0         8
# 11.0        8
# 55.0        7
# 9.0         7
# 31.0        6
# 8.0         6
# 23.0        5
# 56.0        5
# 14.0        5
# 4.0         5
# 53.0        4
# 7.0         4
# 52.0        4
# 24.0        4
# 43.0        3
# 54.0        3
# 32.0        3
# 13.0        3
# 16.0        3
# 17.0        2
# 33.0        2
# 18.0        2
# 22.0        2
# 36.0        1
# 42.0        1
# 48.0        1
# 44.0        1
# 41.0        1
# 47.0        1
# 46.0        1
# 38.0        1
# 34.0        1
# Name: count, dtype: int64
#
#
# Value counts for b15b1:
# b15b1
# 0.0     16219
# 2.0      1081
# 1.0       964
# NaN       340
# 3.0       316
# 4.0       231
# 5.0        99
# 6.0        93
# 8.0        57
# 10.0       24
# 12.0       18
# 7.0        13
# 9.0        11
# 20.0        5
# 11.0        4
# 16.0        3
# 15.0        3
# 24.0        3
# 19.0        1
# 18.0        1
# 22.0        1
# Name: count, dtype: int64
#
#
# Value counts for b15b2:
# b15b2
# 0.0     17651
# 30.0      786
# NaN       420
# 20.0      153
# 40.0      107
# 10.0       92
# 50.0       46
# 45.0       44
# 15.0       32
# 5.0        22
# 1.0        19
# 24.0       11
# 12.0       10
# 2.0        10
# 25.0       10
# 18.0        7
# 35.0        7
# 36.0        4
# 11.0        4
# 3.0         4
# 4.0         4
# 6.0         4
# 14.0        4
# 17.0        4
# 42.0        3
# 55.0        3
# 48.0        3
# 56.0        3
# 21.0        2
# 13.0        2
# 23.0        2
# 9.0         2
# 19.0        2
# 39.0        1
# 52.0        1
# 29.0        1
# 22.0        1
# 32.0        1
# 38.0        1
# 33.0        1
# 27.0        1
# 34.0        1
# 31.0        1
# Name: count, dtype: int64
#
#
# Value counts for b15c1:
# b15c1
# 0.0     11082
# 1.0      5137
# 2.0      1640
# 3.0       535
# NaN       497
# 4.0       219
# 5.0       174
# 10.0       45
# 6.0        37
# 7.0        22
# 12.0       22
# 8.0        19
# 9.0        15
# 20.0       10
# 11.0        9
# 13.0        9
# 24.0        5
# 14.0        2
# 22.0        2
# 19.0        2
# 17.0        2
# 15.0        1
# 23.0        1
# Name: count, dtype: int64
#
#
# Value counts for b15c2:
# b15c2
# 0.0     12576
# 30.0     3409
# 40.0      732
# 20.0      669
# 45.0      591
# NaN       428
# 10.0      385
# 50.0      213
# 15.0      148
# 5.0        71
# 25.0       44
# 35.0       29
# 1.0        28
# 3.0        16
# 2.0        13
# 11.0       11
# 4.0        10
# 12.0       10
# 22.0        9
# 24.0        8
# 9.0         6
# 59.0        6
# 55.0        6
# 18.0        6
# 16.0        5
# 13.0        4
# 27.0        4
# 21.0        3
# 28.0        3
# 36.0        3
# 58.0        3
# 6.0         3
# 14.0        3
# 34.0        3
# 8.0         3
# 31.0        3
# 54.0        3
# 43.0        2
# 23.0        2
# 38.0        2
# 33.0        2
# 53.0        1
# 32.0        1
# 49.0        1
# 52.0        1
# 44.0        1
# 26.0        1
# 41.0        1
# 56.0        1
# 19.0        1
# 37.0        1
# 7.0         1
# 51.0        1
# Name: count, dtype: int64
#
#
# Value counts for b15d1:
# b15d1
# 0.0     9715
# 1.0     5747
# 2.0     2123
# 3.0      701
# NaN      529
# 4.0      226
# 5.0      208
# 10.0      59
# 6.0       46
# 8.0       28
# 7.0       26
# 12.0      21
# 20.0      13
# 11.0      11
# 9.0        7
# 24.0       6
# 19.0       4
# 13.0       4
# 15.0       4
# 18.0       3
# 16.0       2
# 23.0       1
# 14.0       1
# 17.0       1
# 22.0       1
# Name: count, dtype: int64
#
#
# Value counts for b15d2:
# b15d2
# 0.0     11379
# 30.0     4761
# 20.0      828
# 10.0      519
# NaN       448
# 40.0      435
# 50.0      270
# 45.0      243
# 15.0      190
# 5.0        82
# 25.0       47
# 35.0       41
# 1.0        38
# 12.0       24
# 2.0        14
# 3.0        14
# 11.0       12
# 24.0       10
# 23.0        8
# 55.0        8
# 8.0         8
# 4.0         8
# 32.0        7
# 13.0        6
# 31.0        5
# 36.0        5
# 14.0        5
# 33.0        5
# 21.0        4
# 18.0        4
# 22.0        4
# 9.0         4
# 7.0         4
# 52.0        4
# 59.0        4
# 6.0         4
# 34.0        4
# 53.0        3
# 27.0        3
# 43.0        3
# 19.0        2
# 37.0        2
# 44.0        2
# 26.0        2
# 41.0        2
# 17.0        2
# 16.0        2
# 58.0        2
# 42.0        1
# 48.0        1
# 28.0        1
# 47.0        1
# 29.0        1
# 39.0        1
# Name: count, dtype: int64
#
#
# Value counts for b15e1:
# b15e1
# 0.0     11798
# 1.0      3484
# 2.0      1865
# 3.0       805
# NaN       465
# 5.0       320
# 4.0       316
# 6.0        98
# 10.0       71
# 8.0        65
# 7.0        48
# 12.0       45
# 9.0        26
# 20.0       20
# 11.0       13
# 24.0       12
# 15.0        8
# 13.0        7
# 14.0        5
# 23.0        3
# 16.0        3
# 19.0        3
# 18.0        2
# 21.0        2
# 17.0        2
# 22.0        1
# Name: count, dtype: int64
#
#
# Value counts for b15e2:
# b15e2
# 0.0     13723
# 30.0     3128
# 20.0      573
# NaN       454
# 10.0      420
# 40.0      339
# 50.0      233
# 15.0      121
# 45.0      110
# 5.0        78
# 25.0       40
# 35.0       33
# 1.0        25
# 2.0        17
# 3.0        16
# 4.0        13
# 59.0       11
# 11.0       11
# 12.0       11
# 55.0       11
# 13.0       10
# 6.0         9
# 32.0        8
# 21.0        7
# 48.0        6
# 24.0        6
# 52.0        5
# 7.0         5
# 8.0         5
# 23.0        5
# 33.0        4
# 9.0         4
# 58.0        3
# 56.0        3
# 16.0        3
# 36.0        3
# 42.0        3
# 27.0        3
# 43.0        2
# 47.0        2
# 49.0        2
# 19.0        2
# 18.0        2
# 28.0        2
# 54.0        2
# 34.0        2
# 22.0        2
# 14.0        1
# 57.0        1
# 38.0        1
# 44.0        1
# 39.0        1
# 17.0        1
# 46.0        1
# 51.0        1
# 37.0        1
# 31.0        1
# Name: count, dtype: int64
#
#
# Value counts for b15f1:
# b15f1
# 0.0     14194
# 1.0      2287
# 2.0      1226
# 3.0       523
# NaN       428
# 4.0       236
# 5.0       230
# 6.0        81
# 10.0       64
# 8.0        43
# 12.0       39
# 7.0        34
# 9.0        33
# 24.0       18
# 11.0       13
# 20.0        8
# 13.0        7
# 15.0        6
# 19.0        5
# 14.0        3
# 21.0        3
# 16.0        2
# 22.0        1
# 23.0        1
# 90.0        1
# 17.0        1
# Name: count, dtype: int64
#
#
# Value counts for b15f2:
# b15f2
# 0.0     15544
# 30.0     2063
# NaN       425
# 20.0      368
# 10.0      314
# 40.0      227
# 50.0      149
# 15.0       74
# 5.0        64
# 45.0       62
# 1.0        18
# 25.0       16
# 35.0       13
# 12.0       12
# 2.0        12
# 59.0       11
# 6.0         9
# 8.0         9
# 55.0        9
# 11.0        8
# 7.0         7
# 3.0         6
# 24.0        6
# 4.0         6
# 48.0        5
# 33.0        5
# 32.0        4
# 36.0        3
# 19.0        3
# 16.0        3
# 23.0        3
# 9.0         3
# 17.0        3
# 34.0        2
# 43.0        2
# 18.0        2
# 21.0        2
# 31.0        2
# 29.0        2
# 56.0        1
# 49.0        1
# 27.0        1
# 13.0        1
# 58.0        1
# 46.0        1
# 52.0        1
# 28.0        1
# 26.0        1
# 53.0        1
# 14.0        1
# Name: count, dtype: int64
#
#
# Value counts for b15g1:
# b15g1
# 0.0     11431
# 1.0      4055
# 2.0      1667
# 3.0       752
# NaN       586
# 4.0       300
# 5.0       277
# 6.0        77
# 10.0       76
# 9.0        46
# 7.0        45
# 8.0        43
# 12.0       42
# 11.0       21
# 24.0       18
# 20.0       16
# 15.0       10
# 14.0        6
# 13.0        5
# 19.0        3
# 21.0        3
# 23.0        3
# 16.0        2
# 18.0        2
# 22.0        1
# Name: count, dtype: int64
#
#
# Value counts for b15g2:
# b15g2
# 0.0     11190
# 30.0     4111
# 20.0     1105
# 10.0      906
# NaN       436
# 40.0      413
# 50.0      340
# 15.0      285
# 45.0      152
# 5.0       148
# 25.0       63
# 35.0       50
# 1.0        40
# 3.0        26
# 12.0       21
# 2.0        17
# 6.0        15
# 9.0        12
# 59.0       12
# 8.0        10
# 55.0       10
# 13.0        8
# 11.0        8
# 24.0        8
# 23.0        7
# 21.0        7
# 32.0        6
# 34.0        5
# 31.0        5
# 58.0        5
# 4.0         5
# 7.0         5
# 36.0        4
# 43.0        4
# 57.0        4
# 33.0        4
# 46.0        4
# 22.0        3
# 42.0        3
# 52.0        3
# 54.0        3
# 28.0        3
# 49.0        2
# 48.0        2
# 16.0        2
# 17.0        2
# 53.0        2
# 44.0        2
# 47.0        1
# 14.0        1
# 56.0        1
# 29.0        1
# 26.0        1
# 18.0        1
# 41.0        1
# 37.0        1
# 39.0        1
# Name: count, dtype: int64
#
#
# Value counts for b16a1:
# b16a1
# 0.0     11473
# 1.0      2973
# 2.0      2239
# 3.0      1089
# 4.0       588
# NaN       387
# 5.0       337
# 6.0       172
# 8.0        74
# 10.0       49
# 7.0        42
# 9.0        16
# 12.0       15
# 11.0       10
# 20.0        6
# 24.0        4
# 14.0        3
# 15.0        2
# 23.0        2
# 13.0        2
# 16.0        1
# 19.0        1
# 17.0        1
# 22.0        1
# Name: count, dtype: int64
#
#
# Value counts for b16a2:
# b16a2
# 0.0     15202
# 30.0     2385
# NaN       511
# 20.0      321
# 40.0      260
# 10.0      232
# 50.0      168
# 15.0       90
# 45.0       89
# 5.0        36
# 25.0       33
# 35.0       18
# 1.0        17
# 3.0        13
# 2.0        11
# 55.0       10
# 7.0         7
# 12.0        6
# 11.0        6
# 23.0        5
# 4.0         5
# 56.0        4
# 22.0        4
# 24.0        4
# 21.0        4
# 59.0        4
# 9.0         4
# 13.0        4
# 6.0         4
# 34.0        3
# 31.0        2
# 36.0        2
# 26.0        2
# 16.0        2
# 14.0        2
# 17.0        2
# 29.0        2
# 18.0        2
# 32.0        2
# 44.0        1
# 53.0        1
# 58.0        1
# 38.0        1
# 39.0        1
# 43.0        1
# 8.0         1
# 51.0        1
# 49.0        1
# Name: count, dtype: int64
#
#
# Value counts for b16b1:
# b16b1
# 0.0     13720
# 2.0      1746
# 1.0       990
# 4.0       878
# 3.0       743
# 6.0       374
# NaN       361
# 5.0       285
# 8.0       147
# 7.0        80
# 10.0       64
# 9.0        38
# 12.0       24
# 11.0       15
# 20.0        4
# 24.0        4
# 15.0        3
# 18.0        3
# 16.0        3
# 13.0        2
# 14.0        2
# 19.0        1
# Name: count, dtype: int64
#
#
# Value counts for b16b2:
# b16b2
# 0.0     17281
# 30.0     1069
# NaN       514
# 20.0      152
# 40.0      123
# 10.0      101
# 50.0       53
# 45.0       46
# 15.0       40
# 5.0        15
# 2.0         9
# 1.0         8
# 35.0        8
# 3.0         8
# 25.0        6
# 6.0         5
# 11.0        4
# 8.0         3
# 22.0        3
# 9.0         3
# 17.0        3
# 32.0        3
# 4.0         2
# 31.0        2
# 7.0         2
# 13.0        2
# 23.0        2
# 55.0        2
# 29.0        2
# 12.0        2
# 18.0        2
# 21.0        2
# 28.0        2
# 34.0        1
# 37.0        1
# 54.0        1
# 56.0        1
# 27.0        1
# 48.0        1
# 59.0        1
# 19.0        1
# Name: count, dtype: int64
#
#
# Value counts for b16c1:
# b16c1
# 0.0     10211
# 1.0      4515
# 2.0      2379
# 3.0       976
# NaN       466
# 4.0       415
# 5.0       268
# 6.0        67
# 10.0       49
# 8.0        43
# 7.0        36
# 9.0        15
# 12.0       15
# 11.0       10
# 13.0        6
# 24.0        4
# 20.0        4
# 15.0        2
# 23.0        2
# 16.0        2
# 19.0        1
# 17.0        1
# Name: count, dtype: int64
#
#
# Value counts for b16c2:
# b16c2
# 0.0     14258
# 30.0     2861
# NaN       523
# 20.0      441
# 40.0      366
# 10.0      275
# 45.0      229
# 50.0      204
# 15.0      102
# 5.0        35
# 25.0       31
# 1.0        22
# 35.0       20
# 11.0       13
# 2.0        11
# 4.0         8
# 55.0        7
# 13.0        7
# 3.0         7
# 6.0         6
# 12.0        5
# 59.0        5
# 9.0         5
# 7.0         4
# 22.0        3
# 32.0        3
# 21.0        3
# 39.0        2
# 24.0        2
# 18.0        2
# 34.0        2
# 31.0        2
# 23.0        2
# 27.0        2
# 14.0        2
# 28.0        2
# 53.0        2
# 16.0        2
# 54.0        2
# 17.0        2
# 42.0        1
# 56.0        1
# 44.0        1
# 46.0        1
# 8.0         1
# 41.0        1
# 48.0        1
# Name: count, dtype: int64
#
#
# Value counts for b16d1:
# b16d1
# 0.0     7565
# 1.0     5822
# 2.0     3266
# 3.0     1282
# NaN      489
# 4.0      438
# 5.0      297
# 6.0      105
# 10.0      58
# 8.0       44
# 7.0       37
# 12.0      20
# 9.0       14
# 11.0      14
# 20.0      13
# 13.0       6
# 14.0       5
# 24.0       4
# 17.0       3
# 16.0       1
# 15.0       1
# 19.0       1
# 22.0       1
# 18.0       1
# Name: count, dtype: int64
#
#
# Value counts for b16d2:
# b16d2
# 0.0     13093
# 30.0     3634
# NaN       562
# 20.0      561
# 40.0      387
# 10.0      356
# 50.0      275
# 45.0      166
# 15.0      127
# 5.0        44
# 25.0       39
# 35.0       32
# 1.0        27
# 2.0        19
# 55.0       16
# 12.0       16
# 3.0        14
# 8.0        10
# 11.0        9
# 4.0         9
# 32.0        9
# 24.0        7
# 21.0        7
# 22.0        6
# 23.0        6
# 13.0        5
# 6.0         5
# 42.0        4
# 18.0        3
# 39.0        3
# 38.0        3
# 26.0        3
# 34.0        3
# 14.0        2
# 19.0        2
# 31.0        2
# 47.0        2
# 36.0        2
# 53.0        2
# 7.0         2
# 33.0        2
# 59.0        2
# 9.0         2
# 49.0        1
# 43.0        1
# 56.0        1
# 54.0        1
# 16.0        1
# 17.0        1
# 29.0        1
# Name: count, dtype: int64
#
#
# Value counts for b16e1:
# b16e1
# 0.0     6326
# 1.0     4829
# 2.0     3731
# 3.0     1864
# 4.0      841
# 5.0      677
# NaN      436
# 6.0      226
# 8.0      126
# 10.0     111
# 7.0       83
# 9.0       67
# 12.0      56
# 11.0      22
# 24.0      18
# 20.0      17
# 15.0      15
# 13.0      12
# 14.0       8
# 18.0       6
# 16.0       5
# 19.0       4
# 22.0       3
# 21.0       2
# 17.0       2
# Name: count, dtype: int64
#
#
# Value counts for b16e2:
# b16e2
# 0.0     13594
# 30.0     3252
# NaN       605
# 20.0      463
# 40.0      384
# 10.0      314
# 50.0      309
# 45.0      127
# 15.0       81
# 5.0        55
# 25.0       49
# 35.0       27
# 2.0        23
# 1.0        20
# 3.0        17
# 12.0       15
# 11.0       12
# 4.0         9
# 8.0         9
# 59.0        8
# 6.0         7
# 7.0         7
# 32.0        7
# 21.0        6
# 13.0        6
# 9.0         6
# 17.0        5
# 55.0        5
# 24.0        5
# 42.0        5
# 14.0        4
# 33.0        4
# 23.0        4
# 48.0        4
# 22.0        4
# 18.0        4
# 56.0        4
# 34.0        3
# 36.0        3
# 38.0        3
# 37.0        2
# 57.0        2
# 54.0        2
# 52.0        2
# 19.0        1
# 28.0        1
# 58.0        1
# 31.0        1
# 16.0        1
# 39.0        1
# 46.0        1
# 49.0        1
# 51.0        1
# 44.0        1
# Name: count, dtype: int64
#
#
# Value counts for b16f1:
# b16f1
# 0.0     9345
# 1.0     3818
# 2.0     2675
# 3.0     1296
# 4.0      583
# 5.0      530
# NaN      419
# 6.0      199
# 8.0      143
# 10.0     122
# 7.0       98
# 12.0      81
# 9.0       52
# 24.0      29
# 11.0      21
# 15.0      15
# 14.0      14
# 20.0      12
# 13.0      12
# 21.0       5
# 18.0       5
# 16.0       5
# 22.0       4
# 19.0       3
# 23.0       1
# Name: count, dtype: int64
#
#
# Value counts for b16f2:
# b16f2
# 0.0     14966
# 30.0     2575
# NaN       570
# 20.0      355
# 10.0      238
# 40.0      224
# 50.0      198
# 45.0       74
# 15.0       72
# 5.0        33
# 25.0       21
# 35.0       20
# 1.0        20
# 12.0       12
# 2.0        12
# 59.0       11
# 55.0        8
# 11.0        7
# 21.0        7
# 3.0         5
# 26.0        5
# 23.0        4
# 24.0        4
# 19.0        3
# 17.0        3
# 4.0         3
# 13.0        3
# 32.0        3
# 6.0         3
# 8.0         3
# 38.0        2
# 22.0        2
# 56.0        2
# 7.0         2
# 18.0        2
# 41.0        2
# 42.0        1
# 31.0        1
# 39.0        1
# 44.0        1
# 53.0        1
# 37.0        1
# 27.0        1
# 54.0        1
# 46.0        1
# 33.0        1
# 34.0        1
# 52.0        1
# 9.0         1
# Name: count, dtype: int64
#
#
# Value counts for b16g1:
# b16g1
# 0.0     7754
# 1.0     5571
# 2.0     2789
# 3.0     1200
# NaN      571
# 4.0      539
# 5.0      443
# 6.0      161
# 10.0     106
# 8.0       86
# 7.0       64
# 9.0       51
# 12.0      48
# 24.0      24
# 20.0      21
# 11.0      16
# 13.0      10
# 15.0       9
# 14.0       5
# 16.0       4
# 18.0       4
# 22.0       3
# 23.0       3
# 17.0       3
# 21.0       2
# Name: count, dtype: int64
#
#
# Value counts for b16g2:
# b16g2
# 0.0     11496
# 30.0     4230
# 20.0      906
# 10.0      561
# NaN       553
# 40.0      543
# 50.0      396
# 15.0      172
# 45.0      146
# 5.0        85
# 25.0       63
# 35.0       51
# 1.0        35
# 55.0       17
# 3.0        15
# 12.0       14
# 4.0        14
# 6.0        14
# 9.0        13
# 11.0       11
# 2.0        11
# 8.0        10
# 32.0        9
# 18.0        9
# 23.0        8
# 13.0        8
# 21.0        7
# 24.0        6
# 59.0        6
# 7.0         6
# 44.0        5
# 56.0        5
# 48.0        5
# 22.0        5
# 31.0        5
# 41.0        5
# 26.0        3
# 36.0        3
# 43.0        3
# 27.0        3
# 42.0        3
# 16.0        2
# 54.0        2
# 28.0        2
# 14.0        2
# 37.0        2
# 19.0        2
# 46.0        2
# 53.0        2
# 38.0        2
# 17.0        1
# 33.0        1
# 49.0        1
# 58.0        1
# 51.0        1
# 34.0        1
# 47.0        1
# 57.0        1
# 39.0        1
# Name: count, dtype: int64
#
#
# Value counts for b1701:
# b1701
# 1.0    8397
# 2.0    5251
# 3.0    3785
# 4.0     947
# NaN     675
# 5.0     432
# Name: count, dtype: int64
#
#
# Value counts for b1702:
# b1702
# 1.0    7105
# 3.0    4084
# 2.0    4071
# 4.0    2201
# 5.0    1304
# NaN     722
# Name: count, dtype: int64
#
#
# Value counts for b18a:
# b18a
# 8.0     7117
# 7.0     4072
# 9.0     3425
# 6.0     2319
# 10.0    1162
# 5.0      526
# NaN      288
# 11.0     123
# 12.0     118
# 4.0       98
# 0.0       57
# 2.0       29
# 1.0       27
# 3.0       25
# 22.0      17
# 13.0      12
# 21.0      12
# 24.0      11
# 20.0       9
# 18.0       9
# 23.0       8
# 14.0       8
# 16.0       5
# 15.0       5
# 19.0       3
# 41.0       1
# 17.0       1
# Name: count, dtype: int64
#
#
# Value counts for b18b:
# b18b
# 0.0     11134
# 30.0     5155
# NaN       690
# 20.0      596
# 10.0      457
# 40.0      354
# 50.0      284
# 45.0      170
# 15.0      135
# 5.0        67
# 35.0       58
# 25.0       57
# 1.0        20
# 3.0        19
# 12.0       18
# 11.0       17
# 59.0       16
# 55.0       14
# 13.0       14
# 24.0       12
# 23.0       12
# 2.0        11
# 8.0        11
# 6.0        10
# 21.0       10
# 48.0        9
# 32.0        9
# 36.0        9
# 9.0         8
# 14.0        7
# 54.0        7
# 58.0        6
# 26.0        6
# 31.0        6
# 43.0        6
# 38.0        5
# 42.0        5
# 56.0        5
# 4.0         5
# 33.0        4
# 17.0        4
# 27.0        4
# 52.0        4
# 53.0        4
# 47.0        4
# 7.0         3
# 28.0        3
# 16.0        3
# 51.0        3
# 18.0        3
# 39.0        3
# 41.0        2
# 46.0        2
# 34.0        2
# 22.0        1
# 49.0        1
# 37.0        1
# 57.0        1
# 44.0        1
# Name: count, dtype: int64
#
#
# Value counts for b1900:
# b1900
# 1.0    10221
# 0.0     9154
# NaN      112
# Name: count, dtype: int64
#
#
# Value counts for b1901:
# b1901
# 0.0    18609
# 1.0      766
# NaN      112
# Name: count, dtype: int64
#
#
# Value counts for b1902:
# b1902
# 0.0    15457
# 1.0     3918
# NaN      112
# Name: count, dtype: int64
#
#
# Value counts for b1903:
# b1903
# 0.0    17247
# 1.0     2128
# NaN      112
# Name: count, dtype: int64
#
#
# Value counts for b1904:
# b1904
# 0.0    14851
# 1.0     4524
# NaN      112
# Name: count, dtype: int64
#
#
# Value counts for b1905:
# b1905
# 0.0    18001
# 1.0     1374
# NaN      112
# Name: count, dtype: int64
#
#
# Value counts for b1906:
# b1906
# 0.0    18445
# 1.0      930
# NaN      112
# Name: count, dtype: int64
#
#
# Value counts for b1907:
# b1907
# 0.0    17317
# 1.0     2058
# NaN      112
# Name: count, dtype: int64
#
#
# Value counts for b1908:
# b1908
# 0.0    18499
# 1.0      876
# NaN      112
# Name: count, dtype: int64
#
#
# Value counts for b1909:
# b1909
# 0.0    18913
# 1.0      462
# NaN      112
# Name: count, dtype: int64
#
#
# Value counts for b1910:
# b1910
# 0.0    17726
# 1.0     1649
# NaN      112
# Name: count, dtype: int64
#
#
# Value counts for b1911:
# b1911
# 0.0    18370
# 1.0     1005
# NaN      112
# Name: count, dtype: int64
#
#
# Value counts for b2000:
# b2000
# 0.0    16830
# 1.0     2571
# NaN       86
# Name: count, dtype: int64
#
#
# Value counts for b2001:
# b2001
# 0.0    16226
# 1.0     3175
# NaN       86
# Name: count, dtype: int64
#
#
# Value counts for b2002:
# b2002
# 0.0    13309
# 1.0     6092
# NaN       86
# Name: count, dtype: int64
#
#
# Value counts for b2003:
# b2003
# 0.0    17229
# 1.0     2172
# NaN       86
# Name: count, dtype: int64
#
#
# Value counts for b2004:
# b2004
# 0.0    12903
# 1.0     6498
# NaN       86
# Name: count, dtype: int64
#
#
# Value counts for b2005:
# b2005
# 0.0    15681
# 1.0     3719
# NaN       87
# Name: count, dtype: int64
#
#
# Value counts for b2006:
# b2006
# 0.0    11740
# 1.0     7661
# NaN       86
# Name: count, dtype: int64
#
#
# Value counts for b2007:
# b2007
# 0.0    17673
# 1.0     1728
# NaN       86
# Name: count, dtype: int64
#
#
# Value counts for b2101:
# b2101
# 0.0    12949
# 1.0     6378
# NaN      160
# Name: count, dtype: int64
#
#
# Value counts for b2102:
# b2102
# 0.0    17249
# 1.0     2078
# NaN      160
# Name: count, dtype: int64
#
#
# Value counts for b2103:
# b2103
# 1.0    10354
# 0.0     8973
# NaN      160
# Name: count, dtype: int64
#
#
# Value counts for b2104:
# b2104
# 0.0    15735
# 1.0     3592
# NaN      160
# Name: count, dtype: int64
#
#
# Value counts for b2105:
# b2105
# 1.0    11753
# 0.0     7574
# NaN      160
# Name: count, dtype: int64
#
#
# Value counts for b2106:
# b2106
# 0.0    15945
# 1.0     3382
# NaN      160
# Name: count, dtype: int64
#
#
# Value counts for b2201:
# b2201
# 2.0    5680
# 1.0    5667
# 4.0    5393
# 3.0    2535
# NaN     212
# Name: count, dtype: int64
#
#
# Value counts for b2202:
# b2202
# 1.0    8390
# 2.0    5169
# 4.0    3247
# 3.0    2283
# NaN     398
# Name: count, dtype: int64
#
#
# Value counts for b2301:
# b2301
# 3.0    9608
# 2.0    9223
# 1.0     577
# NaN      79
# Name: count, dtype: int64
#
#
# Value counts for b2302:
# b2302
# 2.0    10168
# 3.0     7749
# 1.0     1466
# NaN      104
# Name: count, dtype: int64
#
#
# Value counts for b2303:
# b2303
# 3.0    9732
# 2.0    7706
# 1.0    1936
# NaN     113
# Name: count, dtype: int64
#
#
# Value counts for b2304:
# b2304
# 2.0    8997
# 3.0    8600
# 1.0    1739
# NaN     151
# Name: count, dtype: int64
#
#
# Value counts for b2305:
# b2305
# 2.0    9600
# 3.0    6070
# 1.0    3706
# NaN     111
# Name: count, dtype: int64
#
#
# Value counts for b2306:
# b2306
# 2.0    9942
# 3.0    5632
# 1.0    3776
# NaN     137
# Name: count, dtype: int64
#
#
# Value counts for b2307:
# b2307
# 3.0    12438
# 2.0     5553
# 1.0     1250
# NaN      246
# Name: count, dtype: int64
#
#
# Value counts for b2308:
# b2308
# 2.0    8696
# 3.0    8687
# 1.0    2000
# NaN     104
# Name: count, dtype: int64
#
#
# Value counts for b24a1:
# b24a1
# 2.0    9303
# 3.0    7593
# 1.0    2293
# NaN     298
# Name: count, dtype: int64
#
#
# Value counts for b24b1:
# b24b1
# 2.0    9420
# 1.0    4642
# 3.0    4159
# NaN    1266
# Name: count, dtype: int64
#
#
# Value counts for b24a2:
# b24a2
# 2.0    8773
# 3.0    6478
# 1.0    3857
# NaN     379
# Name: count, dtype: int64
#
#
# Value counts for b24b2:
# b24b2
# 2.0    8231
# 1.0    6197
# 3.0    3746
# NaN    1313
# Name: count, dtype: int64
#
#
# Value counts for b24a3:
# b24a3
# 2.0    8318
# 3.0    6670
# 1.0    4067
# NaN     432
# Name: count, dtype: int64
#
#
# Value counts for b24b3:
# b24b3
# 2.0    7915
# 1.0    5767
# 3.0    4463
# NaN    1342
# Name: count, dtype: int64
#
#
# Value counts for b24a4:
# b24a4
# 2.0    6932
# 3.0    6767
# 1.0    5396
# NaN     392
# Name: count, dtype: int64
#
#
# Value counts for b24b4:
# b24b4
# 2.0    7046
# 1.0    6499
# 3.0    4631
# NaN    1311
# Name: count, dtype: int64
#
#
# Value counts for b24a5:
# b24a5
# 2.0    6809
# 1.0    6170
# 3.0    6143
# NaN     365
# Name: count, dtype: int64
#
#
# Value counts for b24b5:
# b24b5
# 1.0    7335
# 2.0    6752
# 3.0    4130
# NaN    1270
# Name: count, dtype: int64
#
#
# Value counts for b2501:
# b2501
# 3.0    14133
# 2.0     4774
# 1.0      485
# NaN       95
# Name: count, dtype: int64
#
#
# Value counts for b2502:
# b2502
# 3.0    11988
# 2.0     6517
# 1.0      852
# NaN      130
# Name: count, dtype: int64
#
#
# Value counts for b2601:
# b2601
# 1.0    16130
# 2.0     2158
# 5.0      813
# 3.0      212
# NaN       93
# 4.0       81
# Name: count, dtype: int64
#
#
# Value counts for b2602:
# b2602
# 2.0    9013
# 1.0    8106
# 4.0    1103
# 5.0     846
# 3.0     277
# NaN     142
# Name: count, dtype: int64
#
#
# Value counts for b2603:
# b2603
# 1.0    10822
# 2.0     6660
# 4.0      999
# 5.0      636
# 3.0      236
# NaN      134
# Name: count, dtype: int64
#
#
# Value counts for b27:
# b27
# 1.0    6218
# 3.0    5962
# 2.0    5815
# NaN    1154
# 4.0     338
# Name: count, dtype: int64
#
#
# Value counts for b2801:
# b2801
# 6.0    15587
# 5.0     1479
# 2.0      699
# 4.0      634
# 3.0      599
# 1.0      271
# NaN      218
# Name: count, dtype: int64
#
#
# Value counts for b2802:
# b2802
# 1.0    7703
# 6.0    3817
# 5.0    3762
# 4.0    1842
# 2.0    1226
# 3.0     890
# NaN     247
# Name: count, dtype: int64
#
#
# Value counts for b2803:
# b2803
# 6.0    10643
# 5.0     4378
# 4.0     1341
# 1.0     1203
# 3.0      805
# 2.0      779
# NaN      338
# Name: count, dtype: int64
#
#
# Value counts for b2804:
# b2804
# 1.0    6638
# 6.0    4285
# 5.0    3321
# 4.0    2325
# 3.0    1271
# 2.0    1270
# NaN     377
# Name: count, dtype: int64
#
#
# Value counts for b2805:
# b2805
# 1.0    8223
# 2.0    4217
# 3.0    3650
# 4.0    1652
# 6.0     965
# 5.0     499
# NaN     281
# Name: count, dtype: int64
#
#
# Value counts for b2806:
# b2806
# 1.0    8640
# 2.0    3386
# 3.0    3324
# 4.0    2105
# 6.0    1115
# 5.0     685
# NaN     232
# Name: count, dtype: int64
#
#
# Value counts for b29:
# b29
# 5.0    11780
# 4.0     5252
# 3.0     1696
# 2.0      502
# 1.0      203
# NaN       54
# Name: count, dtype: int64
#
#
# Value counts for b30:
# b30
# 2.0    9126
# 1.0    4480
# 3.0    3613
# 4.0    2157
# NaN     111
# Name: count, dtype: int64
#
#
# Value counts for b31:
# b31
# 7.0     7032
# 6.0     3174
# 8.0     2564
# 9.0     2051
# 5.0     1848
# 4.0      905
# 10.0     685
# 3.0      678
# 2.0      335
# NaN      157
# 1.0       58
# Name: count, dtype: int64
#
#
# Value counts for b32:
# b32
# 2.0    6033
# 3.0    5219
# 4.0    4883
# 5.0    2096
# 1.0    1134
# NaN     122
# Name: count, dtype: int64
#
#
# Value counts for b33:
# b33
# 11.0    4818
# 4.0     4757
# 1.0     2455
# 2.0     2090
# 10.0    1265
# 5.0     1004
# 9.0      955
# 3.0      865
# 6.0      496
# 8.0      441
# 7.0      253
# NaN       88
# Name: count, dtype: int64
#
#
# Value counts for b34:
# b34
# 3.0    9529
# 6.0    4134
# 2.0    2386
# 4.0    2050
# 5.0    1200
# 1.0     126
# NaN      62
# Name: count, dtype: int64
#
#
# Value counts for b35:
# b35
# 3.0    9993
# 4.0    5992
# 2.0    3159
# 1.0     257
# NaN      86
# Name: count, dtype: int64
#
#
# Value counts for y:
# y
# 4.000000    2379
# 5.000000    2314
# 4.200000    1867
# 3.800000    1754
# 4.400000    1599
# 3.600000    1515
# 4.600000    1475
# 3.400000    1217
# 3.000000    1126
# 4.800000    1074
# 3.200000     826
# NaN          396
# 2.800000     382
# 2.600000     308
# 1.000000     247
# 2.000000     216
# 2.400000     212
# 2.200000     178
# 1.800000      87
# 1.600000      59
# 1.400000      53
# 3.750000      40
# 3.500000      30
# 1.200000      27
# 4.250000      25
# 4.500000      23
# 3.250000      16
# 2.500000      11
# 4.750000       9
# 2.750000       5
# 3.666667       4
# 3.333333       4
# 2.250000       2
# 4.333333       2
# 2.333333       1
# 4.666667       1
# 1.500000       1
# 1.750000       1
# 2.666667       1
# Name: count, dtype: int64

# %%
import pandas as pd

df.rename(columns={
    'a01': 'gender',
    'a02a': 'birth_year',
    'a02b': 'birth_month',
    'a03': 'ethnicity',
    'a04': 'birthplace',
    'a05': 'hukou_loc',
    'a06': 'hukou_type',
    'a07': 'age_arrival',
    'a08': 'current_residence',
    'a09': 'birthweight_cat',
    'a09a': 'exact_birthweight',
    'a10': 'illness_pre_school',
    'a11': 'fin_cond_pre_school',
    'a13': 'height_cm',
    'a14': 'weight_kg',
    'a15': 'short_sighted',
    'a15a': 'left_eye_strength',
    'a15b': 'right_eye_strength',
    'a16': 'hospitalized_last_yr',
    'a17': 'current_health',
    'b01': 'only_child',
    'b0201': 'older_brothers',
    'b0202': 'younger_brothers',
    'b0203': 'older_sisters',
    'b0204': 'younger_sisters',
    'b03': 'sibling_school_status',
    'b0401': 'live_with_mother',
    'b0402': 'live_with_father',
    'b0403': 'live_with_siblings',
    'b0404': 'live_with_grandparents',
    'b0405': 'live_with_relatives',
    'b0406': 'live_with_nonrelatives',
    'b0501': 'not_live_with_mother',
    'b0502': 'not_live_with_father',
    'b0503': 'not_live_with_siblings',
    'b0504': 'family_live_together',
    'b06': 'mother_education',
    'b07': 'father_education',
    'b08a': 'mother_occupation',
    'b08b': 'father_occupation',
    'b09': 'current_fin_cond',
    'b1001': 'father_drinks',
    'b1002': 'parents_quarrel',
    'b1003': 'parents_get_along',
    'b11': 'own_desk',
    'b12': 'books_owned',
    'b13': 'computer_access',
    'b14a1': 'wkday_homework_hr',
    'b14a2': 'wkday_homework_min',
    'b14b1': 'wkend_homework_hr',
    'b14b2': 'wkend_homework_min',
    'b15a1': 'wkday_assign_hr',
    'b15a2': 'wkday_assign_min',
    'b15b1': 'wkday_cram_hr',
    'b15b2': 'wkday_cram_min',
    'b15c1': 'wkday_sports_hr',
    'b15c2': 'wkday_sports_min',
    'b15d1': 'wkday_reading_hr',
    'b15d2': 'wkday_reading_min',
    'b15e1': 'wkday_tv_hr',
    'b15e2': 'wkday_tv_min',
    'b15f1': 'wkday_gaming_hr',
    'b15f2': 'wkday_gaming_min',
    'b15g1': 'wkday_housework_hr',
    'b15g2': 'wkday_housework_min',
    'b16a1': 'wkend_assign_hr',
    'b16a2': 'wkend_assign_min',
    'b16b1': 'wkend_cram_hr',
    'b16b2': 'wkend_cram_min',
    'b16c1': 'wkend_sports_hr',
    'b16c2': 'wkend_sports_min',
    'b16d1': 'wkend_reading_hr',
    'b16d2': 'wkend_reading_min',
    'b16e1': 'wkend_tv_hr',
    'b16e2': 'wkend_tv_min',
    'b16f1': 'wkend_gaming_hr',
    'b16f2': 'wkend_gaming_min',
    'b16g1': 'wkend_housework_hr',
    'b16g2': 'wkend_housework_min',
    'b1701': 'visit_museums_freq',
    'b1702': 'watch_shows_freq',
    'b18a': 'avg_sleep_hr_night',
    'b18b': 'avg_sleep_min_night',
    'b1900': 'no_extra_activities',
    'b1901': 'math_olympiad',
    'b1902': 'ord_math',
    'b1903': 'chinese_composition',
    'b1904': 'study_english',
    'b1905': 'paint_draw',
    'b1906': 'calligraphy',
    'b1907': 'music_instrument',
    'b1908': 'dancing',
    'b1909': 'play_chess',
    'b1910': 'sports',
    'b1911': 'other_courses',
    'b2000': 'no_hobbies',
    'b2001': 'play_instruments',
    'b2002': 'vocal_dance_act',
    'b2003': 'hobby_calligraphy',
    'b2004': 'hobby_paint_draw',
    'b2005': 'play_chess_hobby',
    'b2006': 'sports_hobby',
    'b2007': 'other_hobbies',
    'b2101': 'cram_courses',
    'b2102': 'attend_camps',
    'b2103': 'help_parents',
    'b2104': 'visit_hometown',
    'b2105': 'stay_home',
    'b2106': 'other_vacation_activities',
    'b2201': 'homework_checkup',
    'b2202': 'homework_guidance',
    'b2301': 'concern_homework',
    'b2302': 'concern_behavior',
    'b2303': 'concern_attendance',
    'b2304': 'concern_home_arrival_time',
    'b2305': 'concern_friends',
    'b2306': 'concern_dress_style',
    'b2307': 'concern_internet_time',
    'b2308': 'concern_tv_time',
    'b24a1': 'school_events_mother',
    'b24b1': 'school_events_father',
    'b24a2': 'friends_relation_mother',
    'b24b2': 'friends_relation_father',
    'b24a3': 'teacher_relation_mother',
    'b24b3': 'teacher_relation_father',
    'b24a4': 'feelings_mother',
    'b24b4': 'feelings_father',
    'b24a5': 'troubles_mother',
    'b24b5': 'troubles_father',
    'b2501': 'relation_with_mother',
    'b2502': 'relation_with_father',
    'b2601': 'chat_when_needed',
    'b2602': 'trouble_help',
    'b2603': 'need_help',
    'b27': 'language_with_parents',
    'b2801': 'family_dinner_freq',
    'b2802': 'family_reading_time',
    'b2803': 'family_tv_time',
    'b2804': 'family_sports_time',
    'b2805': 'visit_science_museums',
    'b2806': 'watch_movies_freq',
    'b29': 'parents_contribution_perception',
    'b30': 'parents_academic_expectation',
    'b31': 'parents_expected_education_level',
    'b32': 'feel_about_expectations',
    'b33': 'expected_future_job',
    'b34': 'expected_living_area',
    'b35': 'parents_confidence',
}, inplace=True)

# %%
activities = [
    ('wkday_homework_hr', 'wkday_homework_min'),
    ('wkend_homework_hr', 'wkend_homework_min'),
    ('wkday_assign_hr', 'wkday_assign_min'),
    ('wkday_cram_hr', 'wkday_cram_min'),
    ('wkday_sports_hr', 'wkday_sports_min'),
    ('wkday_reading_hr', 'wkday_reading_min'),
    ('wkday_tv_hr', 'wkday_tv_min'),
    ('wkday_gaming_hr', 'wkday_gaming_min'),
    ('wkday_housework_hr', 'wkday_housework_min'),
    ('wkend_assign_hr', 'wkend_assign_min'),
    ('wkend_cram_hr', 'wkend_cram_min'),
    ('wkend_sports_hr', 'wkend_sports_min'),
    ('wkend_reading_hr', 'wkend_reading_min'),
    ('wkend_tv_hr', 'wkend_tv_min'),
    ('wkend_gaming_hr', 'wkend_gaming_min'),
    ('wkend_housework_hr', 'wkend_housework_min'),
    ('avg_sleep_hr_night','avg_sleep_min_night')
]
for hr_col, min_col in activities:
    total_min_col = hr_col.replace('_hr', '_total_min')
    df[total_min_col] = df[hr_col] * 60 + df[min_col]

print(df[[col.replace('_hr', '_total_min') for col, _ in activities]].head())

columns_to_drop = [
    'wkday_homework_hr', 'wkday_homework_min',
    'wkend_homework_hr', 'wkend_homework_min',
    'wkday_assign_hr', 'wkday_assign_min',
    'wkday_cram_hr', 'wkday_cram_min',
    'wkday_sports_hr', 'wkday_sports_min',
    'wkday_reading_hr', 'wkday_reading_min',
    'wkday_tv_hr', 'wkday_tv_min',
    'wkday_gaming_hr', 'wkday_gaming_min',
    'wkday_housework_hr', 'wkday_housework_min',
    'wkend_assign_hr', 'wkend_assign_min',
    'wkend_cram_hr', 'wkend_cram_min',
    'wkend_sports_hr', 'wkend_sports_min',
    'wkend_reading_hr', 'wkend_reading_min',
    'wkend_tv_hr', 'wkend_tv_min',
    'wkend_gaming_hr', 'wkend_gaming_min',
    'wkend_housework_hr', 'wkend_housework_min',
    'avg_sleep_hr_night','avg_sleep_min_night'
]

df.drop(columns=columns_to_drop, inplace=True)
# Out:
#    wkday_homework_total_min  wkend_homework_total_min  wkday_assign_total_min  \
# 0                     170.0                      90.0                    50.0
# 1                     180.0                     240.0                     0.0
# 2                      60.0                      60.0                    60.0
# 3                     180.0                     180.0                    60.0
# 4                     130.0                      90.0                     0.0
#
#    wkday_cram_total_min  wkday_sports_total_min  wkday_reading_total_min  \
# 0                  30.0                    90.0                     60.0
# 1                   0.0                    90.0                     60.0
# 2                   0.0                    30.0                     30.0
# 3                   0.0                    60.0                     60.0
# 4                   0.0                   120.0                     60.0
#
#    wkday_tv_total_min  wkday_gaming_total_min  wkday_housework_total_min  \
# 0                15.0                    15.0                       40.0
# 1                 0.0                    30.0                       10.0
# 2                60.0                   120.0                       30.0
# 3                60.0                    40.0                       10.0
# 4                 0.0                    60.0                       30.0
#
#    wkend_assign_total_min  wkend_cram_total_min  wkend_sports_total_min  \
# 0                    30.0                  30.0                    60.0
# 1                    60.0                 180.0                   300.0
# 2                    75.0                   0.0                    60.0
# 3                    60.0                   0.0                     0.0
# 4                     0.0                   0.0                   120.0
#
#    wkend_reading_total_min  wkend_tv_total_min  wkend_gaming_total_min  \
# 0                     60.0                20.0                    30.0
# 1                    120.0                60.0                    60.0
# 2                     60.0               120.0                   120.0
# 3                    120.0                10.0                    40.0
# 4                     60.0                 0.0                   450.0
#
#    wkend_housework_total_min  avg_sleep_total_min_night
# 0                       60.0                      540.0
# 1                      120.0                      540.0
# 2                        0.0                      480.0
# 3                       30.0                      540.0
# 4                       45.0                      450.0
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/804047860.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_min_col] = df[hr_col] * 60 + df[min_col]

# %%
print(df['y'].describe())
# Out:
# count    19091.000000
# mean         3.909886
# std          0.821817
# min          1.000000
# 25%          3.400000
# 50%          4.000000
# 75%          4.600000
# max          5.000000
# Name: y, dtype: float64

# %%
import numpy as np
import matplotlib
from matplotlib import pylab as plt
plt.figure(figsize=(5,3))

df['y'].plot.hist(bins = 15)   # bins = int(np.sqrt(df.shape[0])) 
                        # bins = df['age'].nunique()
plt.xlabel('mental health')
plt.ylabel('count')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
plt.rcParams['text.color'] = 'black'
plt.figure(figsize=(8, 4))
boxplot = sns.boxplot(
    x='relation_with_father',
    y='y',
    data=df,
    palette='cool',  
    width=0.6
)


plt.xticks(ticks=[0, 1, 2], labels=['Not Close', 'OK', 'Close'])  


plt.ylabel('Mental Health', fontsize=12)
plt.xlabel('Relationship with Father', fontsize=12)
plt.title('Relationship Between Mental Health and Relationship with Father', fontsize=14)

plt.grid(True, linestyle='--', linewidth=0.5, color='gray')  
sns.despine(trim=True)  
plt.show()
# Out:
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/2006652071.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   boxplot = sns.boxplot(

# %%
dataset = [
    df[(df['relation_with_father'] == 1) & (df['y'].notna())]['y'].values,
    df[(df['relation_with_father'] == 2) & (df['y'].notna())]['y'].values,
    df[(df['relation_with_father'] == 3) & (df['y'].notna())]['y'].values
]
plt.figure(figsize=(8,5))

plt.violinplot(dataset = dataset,showmedians=True)
plt.xticks([1,2,3],['Not Close','Ok','Close'])
plt.ylabel('Mental Health', fontsize=12)
plt.xlabel('Relationship with Father', fontsize=12)
plt.title('Association Between Mental Health and Relationship with Father', fontsize=14)

plt.grid(True, linestyle='--', linewidth=0.5, color='gray') 
plt.savefig('eda1.png', dpi=300)
plt.show()

# %%
categories = df['parents_quarrel'].dropna().unique()
bin_range = (df['y'].min(),df['y'].max())

plt.figure(figsize=(8,5))
category_labels = {1: 'No', 2: 'Yes'}
for c in categories:
    plt.hist(df[df['parents_quarrel']==c]['y'],alpha=0.5,label=category_labels[c],range=bin_range,bins=15,density=True)
plt.legend(title='Parents Quarrel?')
plt.ylabel('Probability Density')
plt.xlabel('Mental Health')
plt.title('Distribution of Mental Health by Whether Parents Quarrel')
plt.savefig('eda2.png', dpi=300)
plt.show()

# %%
sns.set_style("whitegrid")
plt.rcParams['text.color'] = 'black'
plt.figure(figsize=(8, 4))
boxplot = sns.boxplot(
    x='current_fin_cond',
    y='y',
    data=df,
    palette='cool',  
    width=0.6
)


plt.xticks(ticks=[0, 1, 2,3,4], labels=['Very Poor', 'Somewhat Poor', 'Moderate','Somewhat Rich', 'Very Rich'])  


plt.ylabel('Mental Health', fontsize=12)
plt.xlabel('Current Financial Situation', fontsize=12)
plt.title('Relationship Between Mental Health and Current Financial Situation', fontsize=14)

plt.grid(True, linestyle='--', linewidth=0.5, color='gray')  
sns.despine(trim=True)  
plt.savefig('eda3.png', dpi=300)
plt.show()
# Out:
# /var/folders/zz/tkt706td5tqf3xg_5xkmh_900000gn/T/ipykernel_25922/3006630890.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   boxplot = sns.boxplot(

# %% [markdown]
# ### Data Preprocessing and Splitting

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler
from sklearn.impute import SimpleImputer

onehot_ftrs = [
    'grade9', 'gender', 'ethnicity', 'birthplace', 'hukou_loc', 'hukou_type',
    'current_residence',  'short_sighted', 'hospitalized_last_yr',
     'only_child', 'sibling_school_status', 'live_with_mother',
    'live_with_father', 'live_with_siblings', 'live_with_grandparents',
    'live_with_relatives', 'live_with_nonrelatives', 'not_live_with_mother',
    'not_live_with_father', 'not_live_with_siblings', 'family_live_together',
    'mother_occupation', 'father_occupation', 'father_drinks', 'parents_quarrel',
    'parents_get_along', 'own_desk', 'no_extra_activities', 'math_olympiad',
    'ord_math', 'chinese_composition', 'study_english', 'paint_draw', 'calligraphy',
    'music_instrument', 'dancing', 'play_chess', 'sports', 'other_courses',
    'no_hobbies', 'play_instruments', 'vocal_dance_act', 'hobby_calligraphy',
    'hobby_paint_draw', 'play_chess_hobby', 'sports_hobby', 'other_hobbies',
    'cram_courses', 'attend_camps', 'help_parents', 'visit_hometown', 'stay_home',
    'other_vacation_activities', 'chat_when_needed',
    'trouble_help', 'need_help', 'language_with_parents','illness_pre_school',
]

ordinal_ftrs = [
    'birthweight_cat','current_health','homework_checkup', 'homework_guidance',
    'concern_homework', 'concern_behavior', 'concern_attendance', 'concern_home_arrival_time',
    'concern_friends', 'concern_dress_style', 'concern_internet_time', 'concern_tv_time',
    'school_events_mother', 'school_events_father', 'friends_relation_mother',
    'friends_relation_father', 'teacher_relation_mother', 'teacher_relation_father',
    'feelings_mother', 'feelings_father', 'troubles_mother', 'troubles_father',
    'relation_with_mother', 'relation_with_father', 'fin_cond_pre_school', 'mother_education', 'father_education',
    'current_fin_cond', 'books_owned', 'visit_museums_freq', 'watch_shows_freq',
    'family_dinner_freq', 'family_reading_time', 'family_tv_time', 'family_sports_time',
    'visit_science_museums', 'watch_movies_freq', 'parents_contribution_perception',
    'parents_academic_expectation', 'parents_expected_education_level', 'feel_about_expectations',
    'expected_future_job', 'expected_living_area', 'parents_confidence'
]
std_ftrs = [
    'stcog', 'stdchn', 'stdmat', 'stdeng', 'birth_year', 'age_arrival', 'height_cm', 'weight_kg',
    'avg_sleep_total_min_night', 'wkday_homework_total_min', 'wkend_homework_total_min',
    'wkday_assign_total_min', 'wkday_cram_total_min', 'wkday_sports_total_min', 'wkday_reading_total_min',
    'wkday_tv_total_min', 'wkday_gaming_total_min', 'wkday_housework_total_min', 'wkend_assign_total_min',
    'wkend_cram_total_min', 'wkend_sports_total_min', 'wkend_reading_total_min', 'wkend_tv_total_min',
    'wkend_gaming_total_min', 'wkend_housework_total_min'
]

preprocessor = ColumnTransformer(
    transformers=[
        ('ord', Pipeline([
            ('imputer', SimpleImputer(strategy='constant', fill_value=0)),  # Impute missing values with 0
            ('ordinal', OrdinalEncoder())  # Ordinal encoding
        ]), ordinal_ftrs),
        ('onehot', Pipeline([
            ('imputer', SimpleImputer(strategy='constant', fill_value=-1)),  # Impute missing values with 'missing'
            ('onehot', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))  # One-hot encoding
        ]), onehot_ftrs),
        ('std', StandardScaler(), std_ftrs)])

clf = Pipeline(steps=[('preprocessor', preprocessor)])

# %%
y=df['y']
X = df.loc[:, df.columns != 'y']
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import KFold
random_state =42

# first split to separate out the test set
X_other, X_test, y_other, y_test = train_test_split(X,y,test_size = 0.2,random_state=random_state)
print(X_other.shape,y_other.shape)
print('test set:',X_test.shape,y_test.shape)

# do KFold split on other
kf = KFold(n_splits=4,shuffle=True,random_state=random_state)
for train_index, val_index in kf.split(X_other,y_other):
    X_train = X_other.iloc[train_index]
    y_train = y_other.iloc[train_index]
    X_val = X_other.iloc[val_index]
    y_val = y_other.iloc[val_index]
    print('   training set:',X_train.shape, y_train.shape) 
    print('   validation set:',X_val.shape, y_val.shape) 
    X_train_prep = clf.fit_transform(X_train)
    X_val_prep = clf.transform(X_val)
    X_test_prep = clf.transform(X_test)
    print('Training set:', X_train_prep.shape, y_train.shape) 
    print('Validation set:', X_val_prep.shape, y_val.shape)
    feature_names = preprocessor.get_feature_names_out()
    df_Xtrain = pd.DataFrame(X_train_prep, columns=feature_names)
    print(df_Xtrain.columns)
    print('data dimensions:',df_Xtrain.shape)
    perc_missing_per_ftr = df_Xtrain.isnull().sum(axis=0)/df_Xtrain.shape[0]
    print('fraction of missing values in features:')
    print(perc_missing_per_ftr[perc_missing_per_ftr > 0],len(perc_missing_per_ftr[perc_missing_per_ftr > 0]))
    print('data types of the features with missing values:')
    print(df_Xtrain[perc_missing_per_ftr[perc_missing_per_ftr > 0].index].dtypes)
    frac_missing = sum(df_Xtrain.isnull().sum(axis=1)!=0)/df_Xtrain.shape[0]
    print('fraction of points with missing values:',frac_missing)
# Out:
# (15589, 128) (15589,)
# test set: (3898, 128) (3898,)
#    training set: (11691, 128) (11691,)
#    validation set: (3898, 128) (3898,)
# Training set: (11691, 280) (11691,)
# Validation set: (3898, 280) (3898,)
# Index(['ord__birthweight_cat', 'ord__current_health', 'ord__homework_checkup',
#        'ord__homework_guidance', 'ord__concern_homework',
#        'ord__concern_behavior', 'ord__concern_attendance',
#        'ord__concern_home_arrival_time', 'ord__concern_friends',
#        'ord__concern_dress_style',
#        ...
#        'std__wkday_tv_total_min', 'std__wkday_gaming_total_min',
#        'std__wkday_housework_total_min', 'std__wkend_assign_total_min',
#        'std__wkend_cram_total_min', 'std__wkend_sports_total_min',
#        'std__wkend_reading_total_min', 'std__wkend_tv_total_min',
#        'std__wkend_gaming_total_min', 'std__wkend_housework_total_min'],
#       dtype='object', length=280)
# data dimensions: (11691, 280)
# fraction of missing values in features:
# std__stdchn                       0.024121
# std__stdmat                       0.024891
# std__stdeng                       0.024378
# std__birth_year                   0.021983
# std__age_arrival                  0.045591
# std__height_cm                    0.030878
# std__weight_kg                    0.086562
# std__avg_sleep_total_min_night    0.038919
# std__wkday_homework_total_min     0.050466
# std__wkend_homework_total_min     0.048242
# std__wkday_assign_total_min       0.030622
# std__wkday_cram_total_min         0.027115
# std__wkday_sports_total_min       0.037807
# std__wkday_reading_total_min      0.039689
# std__wkday_tv_total_min           0.036780
# std__wkday_gaming_total_min       0.032846
# std__wkday_housework_total_min    0.042682
# std__wkend_assign_total_min       0.034214
# std__wkend_cram_total_min         0.031905
# std__wkend_sports_total_min       0.037892
# std__wkend_reading_total_min      0.041742
# std__wkend_tv_total_min           0.041057
# std__wkend_gaming_total_min       0.038406
# std__wkend_housework_total_min    0.045591
# dtype: float64 24
# data types of the features with missing values:
# std__stdchn                       float64
# std__stdmat                       float64
# std__stdeng                       float64
# std__birth_year                   float64
# std__age_arrival                  float64
# std__height_cm                    float64
# std__weight_kg                    float64
# std__avg_sleep_total_min_night    float64
# std__wkday_homework_total_min     float64
# std__wkend_homework_total_min     float64
# std__wkday_assign_total_min       float64
# std__wkday_cram_total_min         float64
# std__wkday_sports_total_min       float64
# std__wkday_reading_total_min      float64
# std__wkday_tv_total_min           float64
# std__wkday_gaming_total_min       float64
# std__wkday_housework_total_min    float64
# std__wkend_assign_total_min       float64
# std__wkend_cram_total_min         float64
# std__wkend_sports_total_min       float64
# std__wkend_reading_total_min      float64
# std__wkend_tv_total_min           float64
# std__wkend_gaming_total_min       float64
# std__wkend_housework_total_min    float64
# dtype: object
# fraction of points with missing values: 0.2379608245659054
#    training set: (11692, 128) (11692,)
#    validation set: (3897, 128) (3897,)
# Training set: (11692, 280) (11692,)
# Validation set: (3897, 280) (3897,)
# Index(['ord__birthweight_cat', 'ord__current_health', 'ord__homework_checkup',
#        'ord__homework_guidance', 'ord__concern_homework',
#        'ord__concern_behavior', 'ord__concern_attendance',
#        'ord__concern_home_arrival_time', 'ord__concern_friends',
#        'ord__concern_dress_style',
#        ...
#        'std__wkday_tv_total_min', 'std__wkday_gaming_total_min',
#        'std__wkday_housework_total_min', 'std__wkend_assign_total_min',
#        'std__wkend_cram_total_min', 'std__wkend_sports_total_min',
#        'std__wkend_reading_total_min', 'std__wkend_tv_total_min',
#        'std__wkend_gaming_total_min', 'std__wkend_housework_total_min'],
#       dtype='object', length=280)
# data dimensions: (11692, 280)
# fraction of missing values in features:
# std__stdchn                       0.025573
# std__stdmat                       0.026343
# std__stdeng                       0.026257
# std__birth_year                   0.020783
# std__age_arrival                  0.043791
# std__height_cm                    0.031389
# std__weight_kg                    0.081252
# std__avg_sleep_total_min_night    0.037975
# std__wkday_homework_total_min     0.050633
# std__wkend_homework_total_min     0.048153
# std__wkday_assign_total_min       0.029507
# std__wkday_cram_total_min         0.026941
# std__wkday_sports_total_min       0.036948
# std__wkday_reading_total_min      0.039942
# std__wkday_tv_total_min           0.036948
# std__wkday_gaming_total_min       0.033527
# std__wkday_housework_total_min    0.041567
# std__wkend_assign_total_min       0.031817
# std__wkend_cram_total_min         0.030106
# std__wkend_sports_total_min       0.036777
# std__wkend_reading_total_min      0.039942
# std__wkend_tv_total_min           0.040712
# std__wkend_gaming_total_min       0.037804
# std__wkend_housework_total_min    0.044218
# dtype: float64 24
# data types of the features with missing values:
# std__stdchn                       float64
# std__stdmat                       float64
# std__stdeng                       float64
# std__birth_year                   float64
# std__age_arrival                  float64
# std__height_cm                    float64
# std__weight_kg                    float64
# std__avg_sleep_total_min_night    float64
# std__wkday_homework_total_min     float64
# std__wkend_homework_total_min     float64
# std__wkday_assign_total_min       float64
# std__wkday_cram_total_min         float64
# std__wkday_sports_total_min       float64
# std__wkday_reading_total_min      float64
# std__wkday_tv_total_min           float64
# std__wkday_gaming_total_min       float64
# std__wkday_housework_total_min    float64
# std__wkend_assign_total_min       float64
# std__wkend_cram_total_min         float64
# std__wkend_sports_total_min       float64
# std__wkend_reading_total_min      float64
# std__wkend_tv_total_min           float64
# std__wkend_gaming_total_min       float64
# std__wkend_housework_total_min    float64
# dtype: object
# fraction of points with missing values: 0.23511802942182689
#    training set: (11692, 128) (11692,)
#    validation set: (3897, 128) (3897,)
# Training set: (11692, 280) (11692,)
# Validation set: (3897, 280) (3897,)
# Index(['ord__birthweight_cat', 'ord__current_health', 'ord__homework_checkup',
#        'ord__homework_guidance', 'ord__concern_homework',
#        'ord__concern_behavior', 'ord__concern_attendance',
#        'ord__concern_home_arrival_time', 'ord__concern_friends',
#        'ord__concern_dress_style',
#        ...
#        'std__wkday_tv_total_min', 'std__wkday_gaming_total_min',
#        'std__wkday_housework_total_min', 'std__wkend_assign_total_min',
#        'std__wkend_cram_total_min', 'std__wkend_sports_total_min',
#        'std__wkend_reading_total_min', 'std__wkend_tv_total_min',
#        'std__wkend_gaming_total_min', 'std__wkend_housework_total_min'],
#       dtype='object', length=280)
# data dimensions: (11692, 280)
# fraction of missing values in features:
# std__stdchn                       0.025231
# std__stdmat                       0.026257
# std__stdeng                       0.026086
# std__birth_year                   0.021126
# std__age_arrival                  0.044389
# std__height_cm                    0.031303
# std__weight_kg                    0.084331
# std__avg_sleep_total_min_night    0.035067
# std__wkday_homework_total_min     0.049008
# std__wkend_homework_total_min     0.045416
# std__wkday_assign_total_min       0.028310
# std__wkday_cram_total_min         0.025830
# std__wkday_sports_total_min       0.036350
# std__wkday_reading_total_min      0.038060
# std__wkday_tv_total_min           0.034725
# std__wkday_gaming_total_min       0.031132
# std__wkday_housework_total_min    0.040883
# std__wkend_assign_total_min       0.031047
# std__wkend_cram_total_min         0.029593
# std__wkend_sports_total_min       0.035409
# std__wkend_reading_total_min      0.038402
# std__wkend_tv_total_min           0.038231
# std__wkend_gaming_total_min       0.035323
# std__wkend_housework_total_min    0.043192
# dtype: float64 24
# data types of the features with missing values:
# std__stdchn                       float64
# std__stdmat                       float64
# std__stdeng                       float64
# std__birth_year                   float64
# std__age_arrival                  float64
# std__height_cm                    float64
# std__weight_kg                    float64
# std__avg_sleep_total_min_night    float64
# std__wkday_homework_total_min     float64
# std__wkend_homework_total_min     float64
# std__wkday_assign_total_min       float64
# std__wkday_cram_total_min         float64
# std__wkday_sports_total_min       float64
# std__wkday_reading_total_min      float64
# std__wkday_tv_total_min           float64
# std__wkday_gaming_total_min       float64
# std__wkday_housework_total_min    float64
# std__wkend_assign_total_min       float64
# std__wkend_cram_total_min         float64
# std__wkend_sports_total_min       float64
# std__wkend_reading_total_min      float64
# std__wkend_tv_total_min           float64
# std__wkend_gaming_total_min       float64
# std__wkend_housework_total_min    float64
# dtype: object
# fraction of points with missing values: 0.23511802942182689
#    training set: (11692, 128) (11692,)
#    validation set: (3897, 128) (3897,)
# Training set: (11692, 280) (11692,)
# Validation set: (3897, 280) (3897,)
# Index(['ord__birthweight_cat', 'ord__current_health', 'ord__homework_checkup',
#        'ord__homework_guidance', 'ord__concern_homework',
#        'ord__concern_behavior', 'ord__concern_attendance',
#        'ord__concern_home_arrival_time', 'ord__concern_friends',
#        'ord__concern_dress_style',
#        ...
#        'std__wkday_tv_total_min', 'std__wkday_gaming_total_min',
#        'std__wkday_housework_total_min', 'std__wkend_assign_total_min',
#        'std__wkend_cram_total_min', 'std__wkend_sports_total_min',
#        'std__wkend_reading_total_min', 'std__wkend_tv_total_min',
#        'std__wkend_gaming_total_min', 'std__wkend_housework_total_min'],
#       dtype='object', length=280)
# data dimensions: (11692, 280)
# fraction of missing values in features:
# std__stdchn                       0.025402
# std__stdmat                       0.026172
# std__stdeng                       0.025659
# std__birth_year                   0.021297
# std__age_arrival                  0.045074
# std__height_cm                    0.032159
# std__weight_kg                    0.084759
# std__avg_sleep_total_min_night    0.036606
# std__wkday_homework_total_min     0.050034
# std__wkend_homework_total_min     0.047297
# std__wkday_assign_total_min       0.029336
# std__wkday_cram_total_min         0.026086
# std__wkday_sports_total_min       0.035922
# std__wkday_reading_total_min      0.039087
# std__wkday_tv_total_min           0.036264
# std__wkday_gaming_total_min       0.031303
# std__wkday_housework_total_min    0.040883
# std__wkend_assign_total_min       0.033014
# std__wkend_cram_total_min         0.030277
# std__wkend_sports_total_min       0.036948
# std__wkend_reading_total_min      0.040284
# std__wkend_tv_total_min           0.040369
# std__wkend_gaming_total_min       0.037034
# std__wkend_housework_total_min    0.043791
# dtype: float64 24
# data types of the features with missing values:
# std__stdchn                       float64
# std__stdmat                       float64
# std__stdeng                       float64
# std__birth_year                   float64
# std__age_arrival                  float64
# std__height_cm                    float64
# std__weight_kg                    float64
# std__avg_sleep_total_min_night    float64
# std__wkday_homework_total_min     float64
# std__wkend_homework_total_min     float64
# std__wkday_assign_total_min       float64
# std__wkday_cram_total_min         float64
# std__wkday_sports_total_min       float64
# std__wkday_reading_total_min      float64
# std__wkday_tv_total_min           float64
# std__wkday_gaming_total_min       float64
# std__wkday_housework_total_min    float64
# std__wkend_assign_total_min       float64
# std__wkend_cram_total_min         float64
# std__wkend_sports_total_min       float64
# std__wkend_reading_total_min      float64
# std__wkend_tv_total_min           float64
# std__wkend_gaming_total_min       float64
# std__wkend_housework_total_min    float64
# dtype: object
# fraction of points with missing values: 0.23580225795415669

# %% [markdown]
# ### Missing Values

# %%
print('data dimensions:',df.shape)
perc_missing_per_ftr = df.isnull().sum(axis=0)/df.shape[0]
print('fraction of missing values in features:')
print(perc_missing_per_ftr[perc_missing_per_ftr > 0])
print('data types of the features with missing values:')
print(df[perc_missing_per_ftr[perc_missing_per_ftr > 0].index].dtypes)
frac_missing = sum(df.isnull().sum(axis=1)!=0)/df.shape[0]
print('fraction of points with missing values:',frac_missing)
# Out:
# data dimensions: (19487, 129)
# fraction of missing values in features:
# stdchn                       0.024940
# stdmat                       0.025504
# stdeng                       0.025196
# gender                       0.013907
# birth_year                   0.020783
#                                ...
# wkend_reading_total_min      0.040335
# wkend_tv_total_min           0.040386
# wkend_gaming_total_min       0.036691
# wkend_housework_total_min    0.044337
# avg_sleep_total_min_night    0.036691
# Length: 127, dtype: float64
# data types of the features with missing values:
# stdchn                       float32
# stdmat                       float32
# stdeng                       float32
# gender                       float64
# birth_year                   float64
#                               ...
# wkend_reading_total_min      float64
# wkend_tv_total_min           float64
# wkend_gaming_total_min       float64
# wkend_housework_total_min    float64
# avg_sleep_total_min_night    float64
# Length: 127, dtype: object
# fraction of points with missing values: 0.8134140709190743
